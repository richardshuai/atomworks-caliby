# %%
from openbabel import openbabel
from importlib import reload
import cifutils

openbabel.obErrorLog.SetOutputLevel(0)

# %%
# %%time
# it takes ~2-3mins to initialize the parser
Parser = cifutils.CIFParser()
# Out:
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# ==============================
# *** Open Babel Error  in operator()
#   memory limit exceeded...
# CPU times: user 2min 14s, sys: 2.08 s, total: 2min 16s
# Wall time: 2min 16s

# %%
chains,asmb,covale = Parser.parse('/databases/rcsb/cif/az/5aza.cif.gz')

# %%
chains['B'].atoms,chains['B'].bonds
# Out:
# ({('1',
#    'GLC',
#    'C1'): Atom(name='C1', xyz=[7.201, 16.402, 40.121], occ=1.0, leaving=False, leaving_group=['O1', 'HO1'], parent='O5', element=6, charge=0, hyb=3, hetero=True),
#   ('1',
#    'GLC',
#    'C2'): Atom(name='C2', xyz=[8.054, 17.423, 39.37], occ=1.0, leaving=False, leaving_group=[], parent='O2', element=6, charge=0, hyb=3, hetero=True),
#   ('1',
#    'GLC',
#    'C3'): Atom(name='C3', xyz=[9.517, 17.116, 39.372], occ=1.0, leaving=False, leaving_group=[], parent='O3', element=6, charge=0, hyb=3, hetero=True),
#   ('1',
#    'GLC',
#    'C4'): Atom(name='C4', xyz=[9.939, 16.704, 40.751], occ=1.0, leaving=False, leaving_group=[], parent='O4', element=6, charge=0, hyb=3, hetero=True),
#   ('1',
#    'GLC',
#    'C5'): Atom(name='C5', xyz=[9.107, 15.498, 41.193], occ=1.0, leaving=False, leaving_group=[], parent='O5', element=6, charge=0, hyb=3, hetero=True),
#   ('1',
#    'GLC',
#    'C6'): Atom(name='C6', xyz=[9.464, 15.169, 42.62], occ=1.0, leaving=False, leaving_group=[], parent='O6', element=6, charge=0, hyb=3, hetero=True),
#   ('1',
#    'GLC',
#    'O1'): Atom(name='O1', xyz=[6.964, 15.363, 39.248], occ=1.0, leaving=True, leaving_group=[], parent='C1', element=8, charge=0, hyb=3, hetero=True),
#   ('1',
#    'GLC',
#    'O2'): Atom(name='O2', xyz=[7.663, 17.401, 37.989], occ=1.0, leaving=False, leaving_group=['HO2'], parent='C2', element=8, charge=0, hyb=3, hetero=True),
#   ('1',
#    'GLC',
#    'O3'): Atom(name='O3', xyz=[10.324, 18.239, 38.935], occ=1.0, leaving=False, leaving_group=['HO3'], parent='C3', element=8, charge=0, hyb=3, hetero=True),
#   ('1',
#    'GLC',
#    'O4'): Atom(name='O4', xyz=[11.329, 16.405, 40.652], occ=1.0, leaving=False, leaving_group=['HO4'], parent='C4', element=8, charge=0, hyb=3, hetero=True),
#   ('1',
#    'GLC',
#    'O5'): Atom(name='O5', xyz=[7.76, 15.836, 41.303], occ=1.0, leaving=False, leaving_group=[], parent='C5', element=8, charge=0, hyb=3, hetero=True),
#   ('1',
#    'GLC',
#    'O6'): Atom(name='O6', xyz=[8.861, 13.99, 43.129], occ=1.0, leaving=False, leaving_group=['HO6'], parent='C6', element=8, charge=0, hyb=3, hetero=True),
#   ('1',
#    'GLC',
#    'H1'): Atom(name='H1', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=False, leaving_group=[], parent='C1', element=1, charge=0, hyb=1, hetero=False),
#   ('1',
#    'GLC',
#    'H2'): Atom(name='H2', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=False, leaving_group=[], parent='C2', element=1, charge=0, hyb=1, hetero=False),
#   ('1',
#    'GLC',
#    'H3'): Atom(name='H3', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=False, leaving_group=[], parent='C3', element=1, charge=0, hyb=1, hetero=False),
#   ('1',
#    'GLC',
#    'H4'): Atom(name='H4', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=False, leaving_group=[], parent='C4', element=1, charge=0, hyb=1, hetero=False),
#   ('1',
#    'GLC',
#    'H5'): Atom(name='H5', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=False, leaving_group=[], parent='C5', element=1, charge=0, hyb=1, hetero=False),
#   ('1',
#    'GLC',
#    'H61'): Atom(name='H61', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=False, leaving_group=[], parent='C6', element=1, charge=0, hyb=1, hetero=False),
#   ('1',
#    'GLC',
#    'H62'): Atom(name='H62', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=False, leaving_group=[], parent='C6', element=1, charge=0, hyb=1, hetero=False),
#   ('1',
#    'GLC',
#    'HO1'): Atom(name='HO1', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=True, leaving_group=[], parent='O1', element=1, charge=0, hyb=1, hetero=False),
#   ('1',
#    'GLC',
#    'HO2'): Atom(name='HO2', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=True, leaving_group=[], parent='O2', element=1, charge=0, hyb=1, hetero=False),
#   ('1',
#    'GLC',
#    'HO3'): Atom(name='HO3', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=True, leaving_group=[], parent='O3', element=1, charge=0, hyb=1, hetero=False),
#   ('1',
#    'GLC',
#    'HO6'): Atom(name='HO6', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=True, leaving_group=[], parent='O6', element=1, charge=0, hyb=1, hetero=False),
#   ('2',
#    'GLC',
#    'C1'): Atom(name='C1', xyz=[12.228, 17.365, 41.15], occ=1.0, leaving=False, leaving_group=['O1', 'HO1'], parent='O5', element=6, charge=0, hyb=3, hetero=True),
#   ('2',
#    'GLC',
#    'C2'): Atom(name='C2', xyz=[13.403, 17.341, 40.184], occ=1.0, leaving=False, leaving_group=[], parent='O2', element=6, charge=0, hyb=3, hetero=True),
#   ('2',
#    'GLC',
#    'C3'): Atom(name='C3', xyz=[14.082, 15.979, 40.183], occ=1.0, leaving=False, leaving_group=[], parent='O3', element=6, charge=0, hyb=3, hetero=True),
#   ('2',
#    'GLC',
#    'C4'): Atom(name='C4', xyz=[14.513, 15.724, 41.597], occ=1.0, leaving=False, leaving_group=[], parent='O4', element=6, charge=0, hyb=3, hetero=True),
#   ('2',
#    'GLC',
#    'C5'): Atom(name='C5', xyz=[13.366, 15.797, 42.6], occ=1.0, leaving=False, leaving_group=[], parent='O5', element=6, charge=0, hyb=3, hetero=True),
#   ('2',
#    'GLC',
#    'C6'): Atom(name='C6', xyz=[13.905, 15.722, 44.044], occ=1.0, leaving=False, leaving_group=[], parent='O6', element=6, charge=0, hyb=3, hetero=True),
#   ('2',
#    'GLC',
#    'O2'): Atom(name='O2', xyz=[12.865, 17.662, 38.892], occ=1.0, leaving=False, leaving_group=['HO2'], parent='C2', element=8, charge=0, hyb=3, hetero=True),
#   ('2',
#    'GLC',
#    'O3'): Atom(name='O3', xyz=[15.265, 15.95, 39.343], occ=1.0, leaving=False, leaving_group=['HO3'], parent='C3', element=8, charge=0, hyb=3, hetero=True),
#   ('2',
#    'GLC',
#    'O4'): Atom(name='O4', xyz=[15.048, 14.42, 41.718], occ=1.0, leaving=False, leaving_group=['HO4'], parent='C4', element=8, charge=0, hyb=3, hetero=True),
#   ('2',
#    'GLC',
#    'O5'): Atom(name='O5', xyz=[12.677, 17.038, 42.466], occ=1.0, leaving=False, leaving_group=[], parent='C5', element=8, charge=0, hyb=3, hetero=True),
#   ('2',
#    'GLC',
#    'O6'): Atom(name='O6', xyz=[12.8, 15.53, 44.931], occ=1.0, leaving=False, leaving_group=['HO6'], parent='C6', element=8, charge=0, hyb=3, hetero=True),
#   ('2',
#    'GLC',
#    'H1'): Atom(name='H1', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=False, leaving_group=[], parent='C1', element=1, charge=0, hyb=1, hetero=False),
#   ('2',
#    'GLC',
#    'H2'): Atom(name='H2', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=False, leaving_group=[], parent='C2', element=1, charge=0, hyb=1, hetero=False),
#   ('2',
#    'GLC',
#    'H3'): Atom(name='H3', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=False, leaving_group=[], parent='C3', element=1, charge=0, hyb=1, hetero=False),
#   ('2',
#    'GLC',
#    'H4'): Atom(name='H4', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=False, leaving_group=[], parent='C4', element=1, charge=0, hyb=1, hetero=False),
#   ('2',
#    'GLC',
#    'H5'): Atom(name='H5', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=False, leaving_group=[], parent='C5', element=1, charge=0, hyb=1, hetero=False),
#   ('2',
#    'GLC',
#    'H61'): Atom(name='H61', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=False, leaving_group=[], parent='C6', element=1, charge=0, hyb=1, hetero=False),
#   ('2',
#    'GLC',
#    'H62'): Atom(name='H62', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=False, leaving_group=[], parent='C6', element=1, charge=0, hyb=1, hetero=False),
#   ('2',
#    'GLC',
#    'HO2'): Atom(name='HO2', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=True, leaving_group=[], parent='O2', element=1, charge=0, hyb=1, hetero=False),
#   ('2',
#    'GLC',
#    'HO3'): Atom(name='HO3', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=True, leaving_group=[], parent='O3', element=1, charge=0, hyb=1, hetero=False),
#   ('2',
#    'GLC',
#    'HO4'): Atom(name='HO4', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=True, leaving_group=[], parent='O4', element=1, charge=0, hyb=1, hetero=False),
#   ('2',
#    'GLC',
#    'HO6'): Atom(name='HO6', xyz=[0.0, 0.0, 0.0], occ=0.0, leaving=True, leaving_group=[], parent='O6', element=1, charge=0, hyb=1, hetero=False)},
#  [Bond(a=('1', 'GLC', 'O4'), b=('2', 'GLC', 'C1'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('1', 'GLC', 'C1'), b=('1', 'GLC', 'C2'), aromatic=False, in_ring=True, order=1),
#   Bond(a=('1', 'GLC', 'C1'), b=('1', 'GLC', 'O1'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('1', 'GLC', 'C1'), b=('1', 'GLC', 'O5'), aromatic=False, in_ring=True, order=1),
#   Bond(a=('1', 'GLC', 'C1'), b=('1', 'GLC', 'H1'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('1', 'GLC', 'C2'), b=('1', 'GLC', 'C3'), aromatic=False, in_ring=True, order=1),
#   Bond(a=('1', 'GLC', 'C2'), b=('1', 'GLC', 'O2'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('1', 'GLC', 'C2'), b=('1', 'GLC', 'H2'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('1', 'GLC', 'C3'), b=('1', 'GLC', 'C4'), aromatic=False, in_ring=True, order=1),
#   Bond(a=('1', 'GLC', 'C3'), b=('1', 'GLC', 'O3'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('1', 'GLC', 'C3'), b=('1', 'GLC', 'H3'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('1', 'GLC', 'C4'), b=('1', 'GLC', 'C5'), aromatic=False, in_ring=True, order=1),
#   Bond(a=('1', 'GLC', 'C4'), b=('1', 'GLC', 'O4'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('1', 'GLC', 'C4'), b=('1', 'GLC', 'H4'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('1', 'GLC', 'C5'), b=('1', 'GLC', 'C6'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('1', 'GLC', 'C5'), b=('1', 'GLC', 'O5'), aromatic=False, in_ring=True, order=1),
#   Bond(a=('1', 'GLC', 'C5'), b=('1', 'GLC', 'H5'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('1', 'GLC', 'C6'), b=('1', 'GLC', 'O6'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('1', 'GLC', 'C6'), b=('1', 'GLC', 'H61'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('1', 'GLC', 'C6'), b=('1', 'GLC', 'H62'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('1', 'GLC', 'O1'), b=('1', 'GLC', 'HO1'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('1', 'GLC', 'O2'), b=('1', 'GLC', 'HO2'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('1', 'GLC', 'O3'), b=('1', 'GLC', 'HO3'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('1', 'GLC', 'O6'), b=('1', 'GLC', 'HO6'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('2', 'GLC', 'C1'), b=('2', 'GLC', 'C2'), aromatic=False, in_ring=True, order=1),
#   Bond(a=('2', 'GLC', 'C1'), b=('2', 'GLC', 'O5'), aromatic=False, in_ring=True, order=1),
#   Bond(a=('2', 'GLC', 'C1'), b=('2', 'GLC', 'H1'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('2', 'GLC', 'C2'), b=('2', 'GLC', 'C3'), aromatic=False, in_ring=True, order=1),
#   Bond(a=('2', 'GLC', 'C2'), b=('2', 'GLC', 'O2'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('2', 'GLC', 'C2'), b=('2', 'GLC', 'H2'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('2', 'GLC', 'C3'), b=('2', 'GLC', 'C4'), aromatic=False, in_ring=True, order=1),
#   Bond(a=('2', 'GLC', 'C3'), b=('2', 'GLC', 'O3'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('2', 'GLC', 'C3'), b=('2', 'GLC', 'H3'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('2', 'GLC', 'C4'), b=('2', 'GLC', 'C5'), aromatic=False, in_ring=True, order=1),
#   Bond(a=('2', 'GLC', 'C4'), b=('2', 'GLC', 'O4'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('2', 'GLC', 'C4'), b=('2', 'GLC', 'H4'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('2', 'GLC', 'C5'), b=('2', 'GLC', 'C6'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('2', 'GLC', 'C5'), b=('2', 'GLC', 'O5'), aromatic=False, in_ring=True, order=1),
#   Bond(a=('2', 'GLC', 'C5'), b=('2', 'GLC', 'H5'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('2', 'GLC', 'C6'), b=('2', 'GLC', 'O6'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('2', 'GLC', 'C6'), b=('2', 'GLC', 'H61'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('2', 'GLC', 'C6'), b=('2', 'GLC', 'H62'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('2', 'GLC', 'O2'), b=('2', 'GLC', 'HO2'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('2', 'GLC', 'O3'), b=('2', 'GLC', 'HO3'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('2', 'GLC', 'O4'), b=('2', 'GLC', 'HO4'), aromatic=False, in_ring=False, order=1),
#   Bond(a=('2', 'GLC', 'O6'), b=('2', 'GLC', 'HO6'), aromatic=False, in_ring=False, order=1)])
